# %% [markdown]
# # M1L5 More EDA with Pandas
#
# This notebook will guide you through some essential data manipulation techniques using the Pandas library in Python. We'll be working with the Austin Animal Center Intakes dataset, which contains information about animals entering the Austin Animal Center.
#
# ### **Dataset:** [Austin Animal Center Intakes](https://catalog.data.gov/dataset/austin-animal-center-intakes) -- This is also in your data folder
#
# ### **Objectives:**
#
#  1.  Load and explore the dataset.
#  2.  Use `groupby()` to aggregate data.
#  3.  Create contingency tables using `crosstab()`.
#  4.  Identify and handle duplicate entries.

# %% [markdown]
# ## Step 1:  Import pandas and numpy

# %%
#Import packages 

import pandas as pd
import numpy as np

# %% [markdown]
# ## Step 2:  Load in the data and save it as `df`

# %%
df = pd.read_csv('animalData.csv')

# %% [markdown]
# ## Step 3:  Look at the data (can you think of some methods to do this)

# %%
df.head(50)
# Out:
#    Animal ID      Name                DateTime     MonthYear  \
# 0    A521520      Nina  10/01/2013 07:51:00 AM  October 2013
# 1    A664235       NaN  10/01/2013 08:33:00 AM  October 2013
# 2    A664236       NaN  10/01/2013 08:33:00 AM  October 2013
# 3    A664237       NaN  10/01/2013 08:33:00 AM  October 2013
# 4    A664233    Stevie  10/01/2013 08:53:00 AM  October 2013
# 5    A664238       NaN  10/01/2013 09:33:00 AM  October 2013
# 6    A664234       NaN  10/01/2013 10:37:00 AM  October 2013
# 7    A664256   *Donnie  10/01/2013 10:59:00 AM  October 2013
# 8    A664257    Pippin  10/01/2013 11:01:00 AM  October 2013
# 9    A664266       NaN  10/01/2013 11:09:00 AM  October 2013
# 10   A664258    Sylvio  10/01/2013 11:15:00 AM  October 2013
# 11   A648744    Claire  10/01/2013 11:15:00 AM  October 2013
# 12   A664260       NaN  10/01/2013 11:21:00 AM  October 2013
# 13   A664261       NaN  10/01/2013 11:21:00 AM  October 2013
# 14   A651630   Heather  10/01/2013 11:23:00 AM  October 2013
# 15   A664259  *Petunia  10/01/2013 11:25:00 AM  October 2013
# 16   A664269  *Bismark  10/01/2013 11:28:00 AM  October 2013
# 17   A664262       NaN  10/01/2013 11:45:00 AM  October 2013
# 18   A664263       NaN  10/01/2013 11:45:00 AM  October 2013
# 19   A664264    *Mason  10/01/2013 11:51:00 AM  October 2013
# 20   A664265    *Dixon  10/01/2013 11:51:00 AM  October 2013
# 21   A664267     *Asti  10/01/2013 11:59:00 AM  October 2013
# 22   A664268   *Kochka  10/01/2013 12:05:00 PM  October 2013
# 23   A664271       NaN  10/01/2013 12:35:00 PM  October 2013
# 24   A664272    *Grace  10/01/2013 01:12:00 PM  October 2013
# 25   A664273     Buffy  10/01/2013 01:32:00 PM  October 2013
# 26   A639030      Cate  10/01/2013 01:36:00 PM  October 2013
# 27   A664253     Moose  10/01/2013 01:44:00 PM  October 2013
# 28   A664274  Estrella  10/01/2013 01:48:00 PM  October 2013
# 29   A658012     Lucio  10/01/2013 01:48:00 PM  October 2013
# 30   A636021      Sera  10/01/2013 02:12:00 PM  October 2013
# 31   A664275  Mcdermot  10/01/2013 02:12:00 PM  October 2013
# 32   A664277     *Pogo  10/01/2013 02:12:00 PM  October 2013
# 33   A664280      Coco  10/01/2013 02:34:00 PM  October 2013
# 34   A660220      Jade  10/01/2013 02:35:00 PM  October 2013
# 35   A634503     Otter  10/01/2013 02:49:00 PM  October 2013
# 36   A664281       NaN  10/01/2013 03:13:00 PM  October 2013
# 37   A664282       NaN  10/01/2013 03:13:00 PM  October 2013
# 38   A664283    Juliet  10/01/2013 03:20:00 PM  October 2013
# 39   A664284       NaN  10/01/2013 03:20:00 PM  October 2013
# 40   A664285       NaN  10/01/2013 03:20:00 PM  October 2013
# 41   A664286     Sugar  10/01/2013 03:38:00 PM  October 2013
# 42   A664287     Daisy  10/01/2013 03:38:00 PM  October 2013
# 43   A664288       NaN  10/01/2013 03:52:00 PM  October 2013
# 44   A659642   *Trevor  10/01/2013 03:58:00 PM  October 2013
# 45   A664289       NaN  10/01/2013 04:03:00 PM  October 2013
# 46   A664292       NaN  10/01/2013 04:03:00 PM  October 2013
# 47   A664293    *Romeo  10/01/2013 04:03:00 PM  October 2013
# 48   A664294   *Juliet  10/01/2013 04:03:00 PM  October 2013
# 49   A664295    *Paris  10/01/2013 04:03:00 PM  October 2013
#
#                                       Found Location         Intake Type  \
# 0                            Norht Ec in Austin (TX)               Stray
# 1                                Abia in Austin (TX)               Stray
# 2                                Abia in Austin (TX)               Stray
# 3                                Abia in Austin (TX)               Stray
# 4                     7405 Springtime in Austin (TX)               Stray
# 5                               Outside Jurisdiction               Stray
# 6                     5400 Jimmy Clay in Austin (TX)               Stray
# 7                                        Austin (TX)     Owner Surrender
# 8                            Burleson in Travis (TX)               Stray
# 9                      Payton And 183 in Austin (TX)               Stray
# 10                Fm 1626/Manchaca Rd in Travis (TX)               Stray
# 11                Fm 1626/Manchaca Rd in Travis (TX)               Stray
# 12                 3009 Meldrum St in Del Valle (TX)               Stray
# 13                 3009 Meldrum St in Del Valle (TX)               Stray
# 14                              Outside Jurisdiction     Owner Surrender
# 15                    5001 Creek Bend in Austin (TX)               Stray
# 16                       7500 S Ih 35 in Austin (TX)               Stray
# 17                      4915 Yager Ln in Austin (TX)               Stray
# 18                      4915 Yager Ln in Austin (TX)               Stray
# 19                      4915 Yager Ln in Austin (TX)               Stray
# 20                      4915 Yager Ln in Austin (TX)               Stray
# 21              12501 Tech Ridge Blvd in Austin (TX)               Stray
# 22                                       Austin (TX)               Stray
# 23                    Spirit Of Texas in Austin (TX)               Stray
# 24              12005 Garden Grove Dr in Austin (TX)               Stray
# 25       Berkman Dr & Briarcliff Blvd in Austin (TX)               Stray
# 26                     46Th And Ave G in Austin (TX)               Stray
# 27                                       Austin (TX)       Public Assist
# 28                                       Austin (TX)     Owner Surrender
# 29                     1505 Darold Dr in Austin (TX)               Stray
# 30                1156 W Cesar Chavez in Austin (TX)       Public Assist
# 31                           4905 Alf in Austin (TX)               Stray
# 32                           4905 Alf in Austin (TX)               Stray
# 33  W Pflugerville Pkwy/Zola Ln in Pflugerville (TX)               Stray
# 34                                       Austin (TX)  Euthanasia Request
# 35                                        Manor (TX)     Owner Surrender
# 36             14824 Falling Stone Ln in Travis (TX)               Stray
# 37             14824 Falling Stone Ln in Travis (TX)               Stray
# 38                   1001 Bouldin Ave in Austin (TX)               Stray
# 39                   1001 Bouldin Ave in Austin (TX)               Stray
# 40                   1001 Bouldin Ave in Austin (TX)               Stray
# 41                   16310 Bratton Ln in Austin (TX)               Stray
# 42                   16310 Bratton Ln in Austin (TX)               Stray
# 43                 11612 Gemmer St in Del Valle (TX)               Stray
# 44                                       Austin (TX)     Owner Surrender
# 45                      7903 Taza Trl in Austin (TX)               Stray
# 46                      7903 Taza Trl in Austin (TX)               Stray
# 47                      7903 Taza Trl in Austin (TX)               Stray
# 48                      7903 Taza Trl in Austin (TX)               Stray
# 49                      7903 Taza Trl in Austin (TX)               Stray
#
#    Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0            Normal         Dog   Spayed Female         7 years
# 1            Normal         Cat         Unknown          1 week
# 2            Normal         Cat         Unknown          1 week
# 3            Normal         Cat         Unknown          1 week
# 4           Injured         Dog   Intact Female         3 years
# 5            Normal         Cat         Unknown        4 months
# 6           Injured         Dog     Intact Male         8 years
# 7            Normal         Cat   Neutered Male        17 years
# 8            Normal         Dog   Intact Female         4 years
# 9            Normal         Dog   Intact Female          1 year
# 10           Normal         Dog   Neutered Male         7 years
# 11           Normal         Dog   Spayed Female          1 year
# 12           Normal         Cat   Intact Female         3 weeks
# 13           Normal         Cat   Intact Female         3 weeks
# 14          Injured         Dog   Spayed Female         6 years
# 15           Normal         Dog   Intact Female         5 years
# 16           Normal         Dog   Neutered Male         2 years
# 17           Normal         Cat     Intact Male         1 weeks
# 18           Normal         Cat     Intact Male         1 weeks
# 19           Normal         Cat     Intact Male        2 months
# 20           Normal         Cat     Intact Male        2 months
# 21           Normal         Dog   Intact Female        4 months
# 22           Normal         Cat   Intact Female         3 years
# 23           Normal         Cat   Intact Female          1 week
# 24           Normal         Dog   Spayed Female          1 year
# 25           Normal         Dog   Intact Female          1 year
# 26           Normal         Dog   Spayed Female         7 years
# 27           Normal         Dog   Neutered Male         2 years
# 28           Normal         Dog   Intact Female         8 years
# 29           Normal         Dog   Neutered Male         3 years
# 30           Normal         Dog   Spayed Female          1 year
# 31           Normal         Dog     Intact Male         2 years
# 32           Normal         Dog   Intact Female        8 months
# 33           Normal         Dog   Spayed Female         6 years
# 34          Injured         Dog   Spayed Female          1 year
# 35           Normal         Dog   Spayed Female         2 years
# 36           Normal         Cat     Intact Male         2 years
# 37           Normal         Cat   Intact Female         2 years
# 38          Nursing         Cat   Intact Female          1 year
# 39          Nursing         Cat     Intact Male         0 years
# 40          Nursing         Cat     Intact Male         0 years
# 41           Normal         Dog   Intact Female         2 years
# 42           Normal         Dog   Intact Female        4 months
# 43           Normal         Cat     Intact Male         2 years
# 44           Normal         Dog   Neutered Male         2 years
# 45           Normal         Cat   Intact Female        3 months
# 46           Normal         Cat   Intact Female        9 months
# 47           Normal         Cat     Intact Male         1 month
# 48           Normal         Cat   Intact Female         1 month
# 49           Normal         Cat     Intact Male         1 month
#
#                                  Breed              Color
# 0         Border Terrier/Border Collie          White/Tan
# 1               Domestic Shorthair Mix       Orange/White
# 2               Domestic Shorthair Mix       Orange/White
# 3               Domestic Shorthair Mix       Orange/White
# 4                         Pit Bull Mix         Blue/White
# 5               American Shorthair Mix        Black/White
# 6                    Border Collie Mix        Black/White
# 7               Domestic Shorthair Mix  Brown Tabby/White
# 8                  Podengo Pequeno Mix              Black
# 9              Chihuahua Shorthair Mix               Buff
# 10                      Weimaraner Mix             Silver
# 11                 Anatol Shepherd Mix     White/Tricolor
# 12              Domestic Shorthair Mix        Black/White
# 13              Domestic Shorthair Mix             Tortie
# 14  Labrador Retriever/Chinese Sharpei                Tan
# 15                        Pit Bull Mix              Black
# 16                  Great Pyrenees Mix              White
# 17              Domestic Shorthair Mix       Orange Tabby
# 18              Domestic Shorthair Mix       Orange Tabby
# 19              Domestic Shorthair Mix        Brown Tabby
# 20              Domestic Shorthair Mix        Brown Tabby
# 21                        Pit Bull Mix        White/Black
# 22                    Russian Blue Mix               Blue
# 23              Domestic Shorthair Mix       Orange Tabby
# 24                   Cairn Terrier Mix              Brown
# 25       Dachshund/Chihuahua Shorthair              Brown
# 26                 German Shepherd Mix                Tan
# 27                 Black/Tan Hound Mix        Black/Brown
# 28                  Siberian Husky Mix               Buff
# 29             Chihuahua Shorthair Mix                Red
# 30                        Pit Bull Mix              Brown
# 31             Chihuahua Shorthair Mix           Tricolor
# 32             Chihuahua Shorthair Mix        White/Brown
# 33                Miniature Poodle Mix            Apricot
# 34  Yorkshire Terrier/Miniature Poodle               Gray
# 35                 Norfolk Terrier Mix                Tan
# 36              Domestic Shorthair Mix        Brown Tabby
# 37               Domestic Longhair Mix        Brown Tabby
# 38              Domestic Shorthair Mix        Black/White
# 39              Domestic Shorthair Mix        Black/White
# 40              Domestic Shorthair Mix              Black
# 41             Chihuahua Shorthair Mix        White/Brown
# 42             Chihuahua Shorthair Mix        Brown/White
# 43              Domestic Shorthair Mix         Blue/White
# 44              Dachshund/Basset Hound      Brown Brindle
# 45              Domestic Shorthair Mix  Brown Tabby/White
# 46              Domestic Shorthair Mix  Brown Tabby/White
# 47            Domestic Medium Hair Mix        Black/White
# 48            Domestic Medium Hair Mix              Black
# 49            Domestic Medium Hair Mix  Brown Tabby/White

# %% [markdown]
# ## Step 4:  Count up how many missing values exist in each column (you would need to chain two methods here -- one to check for missing values and the other to sum missing values up)

# %%
print(df.isnull().sum())
# Out:
# Animal ID               0
# Name                49991
# DateTime                0
# MonthYear               0
# Found Location          0
# Intake Type             0
# Intake Condition        0
# Animal Type             0
# Sex upon Intake         1
# Age upon Intake         0
# Breed                   0
# Color                   0
# dtype: int64

# %% [markdown]
# ## Step 5:  Count up the amount of animals by Animal Type

# %%
animal_counts = df['Animal Type'].value_counts()
print(animal_counts)
# Out:
# Animal Type
# Dog          94608
# Cat          69324
# Other         8968
# Bird           878
# Livestock       34
# Name: count, dtype: int64

# %% [markdown]
# ## Step 6:  Create a crosstab showing the count of animal types for each intake condition.

# %%
cross_table = pd.crosstab(df['Animal Type'], df['Intake Condition'])
cross_table
# Out:
# Intake Condition  Aged  Agonal  Behavior  Congenital  Feral  Injured  \
# Animal Type
# Bird                 0       0         0           0      0      249
# Cat                 77       3         8           0    133     4339
# Dog                445       1        73           1     11     5000
# Livestock            0       0         0           0      0        2
# Other                3       0         0           0      1     1215
#
# Intake Condition  Med Attn  Med Urgent  Medical  Neonatal  Neurologic  Normal  \
# Animal Type
# Bird                     0           0        0         1           0     603
# Cat                     27          11      213      1467           5   57032
# Dog                     60          10      391       476           6   83773
# Livestock                0           0        0         1           0      28
# Other                    0           0       10        26           2    5705
#
# Intake Condition  Nursing  Other  Panleuk  Parvo  Pregnant  Sick  Space  \
# Animal Type
# Bird                    0      8        0      0         0    17      0
# Cat                  2559    110        1      0        41  3287      4
# Dog                  1214    229        0     11       129  2756      0
# Livestock               0      0        0      0         0     3      0
# Other                 105      6        0      0         0  1876      0
#
# Intake Condition  Unknown
# Animal Type
# Bird                    0
# Cat                     7
# Dog                    22
# Livestock               0
# Other                  19

# %% [markdown]
# ## Step 7:  Check for duplicate Animal IDs (pay close attention to the syntax here)

# %%
duplicate_ids = df['Animal ID'].duplicated().sum()
print(duplicate_ids)
# Out:
# 17525

# %% [markdown]
# ## Practice Joining Data

# %% [markdown]
# ### Scenario 1
# You have customer data split into two different files (DataFrames),
# and you want to combine them into a single DataFrame for analysis.

# %%
# Run the cell without changes to create the two dataframes 

customers_part1_df = pd.DataFrame({'CustomerID': [101, 102, 103],
                                   'FirstName': ['Alice', 'Bob', 'Charlie'],
                                   'City': ['Anytown', 'Otherville', 'Smallburg']})

customers_part2_df = pd.DataFrame({'CustomerID': [104, 105, 106],
                                   'FirstName': ['David', 'Emily', 'Frank'],
                                   'City': ['Bigcity', 'Townsville', 'Villageton']})

# %% [markdown]
# ### Scenario 1 Task:  Use `pd.concat()` to stack the two dataframes above (afterall they have the same columns)

# %%
all_customers_df = pd.concat([customers_part1_df,customers_part2_df])
all_customers_df
# Out:
#    CustomerID FirstName        City
# 0         101     Alice     Anytown
# 1         102       Bob  Otherville
# 2         103   Charlie   Smallburg
# 0         104     David     Bigcity
# 1         105     Emily  Townsville
# 2         106     Frank  Villageton

# %% [markdown]
# ### Scenario 2

# %% [markdown]
# Combining customer details and loyalty points.

# %%
# Run the cell without changes to create the two dataframes 

customer_details_df = pd.DataFrame({'CustomerID': [101, 102, 103],
                                    'Name': ['Alice', 'Bob', 'Charlie'],
                                    'City': ['Anytown', 'Otherville', 'Smallburg']})

loyalty_points_df = pd.DataFrame({'CustomerID': [101, 102, 103],
                                  'Points': [100, 250, 50]})

# %% [markdown]
# ### Scenario 2 Task :  Merge the DataFrames on CustomerID

# %%
merged_customer_df = pd.merge(customer_details_df,loyalty_points_df,on='CustomerID')
merged_customer_df
# Out:
#    CustomerID     Name        City  Points
# 0         101    Alice     Anytown     100
# 1         102      Bob  Otherville     250
# 2         103  Charlie   Smallburg      50
