# %% [markdown]
# ## 🛠️ Mod5 Data Challenge 5: Cohorts & Retention
#
#
# **Why this activity?**
# You’ll build **cohort retention** from real transaction data to answer: *Are customers coming back after their first purchase?* This extends today’s lecture on Cohorts & Retention to a real dataset.
#
# **Dataset:** UCI Online Retail II.  View more [HERE](https://archive.ics.uci.edu/dataset/502/online+retail+ii)
#
# **Goals — You will be able to:**
# 1) Load & clean real transaction data (remove cancellations, keep positive quantities/prices).
# 2) Build **time‑anchored cohorts** (first purchase period).
# 3) Compute a **cohort retention matrix** (monthly or weekly).
# 4) Explain differences and propose product/marketing actions.
#
# **Interview practice:**
# - **Q1:** Why can MAU look stable while retention collapses?
# - **Q2:** Day/Month‑1 retention fell for the newest cohort—what do you check first?
# - **Q3:** When would you choose weekly vs monthly cohorts?

# %% [markdown]
# ### 👩‍🏫 Instructor-Led Demo (25 minutes)

# %% [markdown]
# ### Step 1:  Load & clean the Online Retail II Excel
#
# We will:
# 1) Read **both sheets** from the Excel file and concatenate.
# 2) Parse dates.
# 3) Drop rows with missing CustomerID and standardize types.
# 4) Create an **activity date** column (we’ll use InvoiceDate).
#
# Note:  We are keeping returns and cancellations in the data (for now) this may affect KPIs (like revenue), which is outside the scope of this cohort exercise but VERY important to point out.

# %%
# import packages per usual 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Path to your downloaded Excel file
DATA_PATH = '/Users/Marcy_Student/Downloads/online_retail_II.xlsx'  

# 1) Read both sheets and concatenate
sheets = ["Year 2009-2010", "Year 2010-2011"]
df_list = [pd.read_excel(DATA_PATH, sheet_name=s, engine="openpyxl") for s in sheets]
df = pd.concat(df_list, ignore_index=True)

# 2) Change InvoiceDate to datetime
df["InvoiceDate"] = pd.to_datetime(df['InvoiceDate'])

# 3) Drop missing CustomerID and standardize types
df = df.dropna(subset=["Customer ID"]).copy()
df["Customer ID"] = df["Customer ID"].astype(int)

# 4) Activity date (alias for clarity)
df["activity_date"] = df["InvoiceDate"]

df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country       activity_date
# 0 2009-12-01 07:45:00   6.95        13085  United Kingdom 2009-12-01 07:45:00
# 1 2009-12-01 07:45:00   6.75        13085  United Kingdom 2009-12-01 07:45:00
# 2 2009-12-01 07:45:00   6.75        13085  United Kingdom 2009-12-01 07:45:00
# 3 2009-12-01 07:45:00   2.10        13085  United Kingdom 2009-12-01 07:45:00
# 4 2009-12-01 07:45:00   1.25        13085  United Kingdom 2009-12-01 07:45:00

# %% [markdown]
# #### Step 2:  Filter for a country (UK) and define cohorts
#
# We will:
# 1) Keep rows where `Country == "United Kingdom"`.
# 2) Define **cohort_month** as each customer’s first activity month.
# 3) Define **activity_month** for each row.
# 4) Compute **month_number** = months since cohort start.
#
# **Speaker Notes:** Cohorts are anchored by **first activity**; “Month 0” is the signup month; “Month 1” is the following month, etc.

# %%
# 1) Country filter
uk_filter = df['Country'] == 'United Kingdom'
df_uk = df[uk_filter].copy()

# 2) First activity month (cohort anchor) per customer
df_uk["cohort_month"] = df_uk.groupby(df_uk['Customer ID'])['activity_date'].transform(min).dt.to_period('M')

# 3) Activity month per row
df_uk["activity_month"] = df_uk['activity_date'].dt.to_period('M')

# 4) Months since cohort start
df_uk["month_number"] = (df_uk["activity_month"] - df_uk["cohort_month"]).apply(lambda x: x.n)

df_uk[["Customer ID","activity_date","cohort_month","activity_month","month_number"]].head()
# Out:
# /var/folders/_z/410cfm6x4fl_4m_6s41fnf4w0000gp/T/ipykernel_23793/107677898.py:6: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df_uk["cohort_month"] = df_uk.groupby(df_uk['Customer ID'])['activity_date'].transform(min).dt.to_period('M')
#    Customer ID       activity_date cohort_month activity_month  month_number
# 0        13085 2009-12-01 07:45:00      2009-12        2009-12             0
# 1        13085 2009-12-01 07:45:00      2009-12        2009-12             0
# 2        13085 2009-12-01 07:45:00      2009-12        2009-12             0
# 3        13085 2009-12-01 07:45:00      2009-12        2009-12             0
# 4        13085 2009-12-01 07:45:00      2009-12        2009-12             0

# %% [markdown]
# **Think:  Why do we see duplicate customer ID's here with the same activity date**?

# %% [markdown]
# #### Step 3:  Build a monthly retention matrix and normalize by cohort size
#
# We will:
# 1) Count **unique active customers** by (`cohort_month`, `month_number`).
# 2) Pivot to cohorts × months.
# 3) Divide each row by **Month 0** to get retention fractions.
#
# **Speaker Notes:** Using unique customers avoids overcounting heavy purchasers; we measure presence, not volume.

# %%
# 1) Unique active customers per (cohort_month, month_number)
cohort_counts_m = df_uk.groupby(["cohort_month","month_number"])["Customer ID"].nunique().reset_index()

# 2) Pivot
retention_m = cohort_counts_m.pivot(index='cohort_month',columns='month_number',values='Customer ID')

# 3) Normalize by cohort size (Month 0)
cohort_size_m = retention_m.iloc[:, 0]
retention_m_frac = retention_m.div(cohort_size_m, axis=0)

retention_m_frac
# Out:
# month_number   0         1         2         3         4         5         6   \
# cohort_month
# 2009-12       1.0  0.373225  0.338742  0.423935  0.392495  0.391481  0.385396
# 2010-01       1.0  0.230769  0.313390  0.316239  0.282051  0.310541  0.267806
# 2010-02       1.0  0.294294  0.222222  0.312312  0.255255  0.216216  0.210210
# 2010-03       1.0  0.218673  0.267813  0.240786  0.235872  0.206388  0.245700
# 2010-04       1.0  0.226415  0.203774  0.162264  0.188679  0.222642  0.271698
# 2010-05       1.0  0.188034  0.175214  0.200855  0.192308  0.256410  0.226496
# 2010-06       1.0  0.201613  0.201613  0.209677  0.229839  0.286290  0.137097
# 2010-07       1.0  0.204969  0.186335  0.291925  0.285714  0.149068  0.093168
# 2010-08       1.0  0.234483  0.317241  0.303448  0.172414  0.137931  0.082759
# 2010-09       1.0  0.300000  0.259091  0.140909  0.090909  0.104545  0.150000
# 2010-10       1.0  0.280702  0.163743  0.114035  0.084795  0.084795  0.137427
# 2010-11       1.0  0.208609  0.089404  0.102649  0.089404  0.089404  0.145695
# 2010-12       1.0  0.076923  0.046154  0.076923  0.092308  0.092308  0.046154
# 2011-01       1.0  0.209677  0.225806  0.225806  0.241935  0.161290  0.145161
# 2011-02       1.0  0.194444  0.175926  0.175926  0.250000  0.166667  0.175926
# 2011-03       1.0  0.245399  0.251534  0.220859  0.208589  0.165644  0.208589
# 2011-04       1.0  0.260870  0.184783  0.206522  0.195652  0.250000  0.184783
# 2011-05       1.0  0.252632  0.231579  0.178947  0.221053  0.200000  0.252632
# 2011-06       1.0  0.287234  0.180851  0.265957  0.223404  0.255319  0.085106
# 2011-07       1.0  0.233333  0.311111  0.311111  0.366667  0.155556       NaN
# 2011-08       1.0  0.348837  0.290698  0.267442  0.186047       NaN       NaN
# 2011-09       1.0  0.333333  0.392857  0.160714       NaN       NaN       NaN
# 2011-10       1.0  0.343590  0.169231       NaN       NaN       NaN       NaN
# 2011-11       1.0  0.175141       NaN       NaN       NaN       NaN       NaN
# 2011-12       1.0       NaN       NaN       NaN       NaN       NaN       NaN
#
# month_number        7         8         9   ...        15        16        17  \
# cohort_month                                ...
# 2009-12       0.354970  0.339757  0.368154  ...  0.295132  0.258621  0.300203
# 2010-01       0.239316  0.287749  0.333333  ...  0.153846  0.222222  0.193732
# 2010-02       0.279279  0.279279  0.285285  ...  0.195195  0.177177  0.174174
# 2010-03       0.302211  0.297297  0.115479  ...  0.169533  0.181818  0.157248
# 2010-04       0.256604  0.109434  0.098113  ...  0.147170  0.135849  0.150943
# 2010-05       0.132479  0.059829  0.068376  ...  0.115385  0.136752  0.170940
# 2010-06       0.080645  0.080645  0.120968  ...  0.104839  0.129032  0.205645
# 2010-07       0.136646  0.118012  0.118012  ...  0.173913  0.242236  0.086957
# 2010-08       0.137931  0.137931  0.137931  ...  0.193103  0.062069       NaN
# 2010-09       0.095455  0.127273  0.140909  ...  0.054545       NaN       NaN
# 2010-10       0.140351  0.111111  0.093567  ...       NaN       NaN       NaN
# 2010-11       0.115894  0.092715  0.092715  ...       NaN       NaN       NaN
# 2010-12       0.076923  0.061538  0.030769  ...       NaN       NaN       NaN
# 2011-01       0.112903  0.129032  0.241935  ...       NaN       NaN       NaN
# 2011-02       0.157407  0.175926  0.185185  ...       NaN       NaN       NaN
# 2011-03       0.214724  0.251534  0.098160  ...       NaN       NaN       NaN
# 2011-04       0.271739  0.119565       NaN  ...       NaN       NaN       NaN
# 2011-05       0.105263       NaN       NaN  ...       NaN       NaN       NaN
# 2011-06            NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2011-07            NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2011-08            NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2011-09            NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2011-10            NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2011-11            NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2011-12            NaN       NaN       NaN  ...       NaN       NaN       NaN
#
# month_number        18        19        20        21        22        23  \
# cohort_month
# 2009-12       0.279919  0.267748  0.255578  0.311359  0.298174  0.400609
# 2010-01       0.173789  0.188034  0.247863  0.185185  0.225071  0.074074
# 2010-02       0.138138  0.234234  0.246246  0.153153  0.063063       NaN
# 2010-03       0.169533  0.206388  0.213759  0.081081       NaN       NaN
# 2010-04       0.162264  0.207547  0.067925       NaN       NaN       NaN
# 2010-05       0.145299  0.051282       NaN       NaN       NaN       NaN
# 2010-06       0.060484       NaN       NaN       NaN       NaN       NaN
# 2010-07            NaN       NaN       NaN       NaN       NaN       NaN
# 2010-08            NaN       NaN       NaN       NaN       NaN       NaN
# 2010-09            NaN       NaN       NaN       NaN       NaN       NaN
# 2010-10            NaN       NaN       NaN       NaN       NaN       NaN
# 2010-11            NaN       NaN       NaN       NaN       NaN       NaN
# 2010-12            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-01            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-02            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-03            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-04            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-05            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-06            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-07            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-08            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-09            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-10            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-11            NaN       NaN       NaN       NaN       NaN       NaN
# 2011-12            NaN       NaN       NaN       NaN       NaN       NaN
#
# month_number        24
# cohort_month
# 2009-12       0.203854
# 2010-01            NaN
# 2010-02            NaN
# 2010-03            NaN
# 2010-04            NaN
# 2010-05            NaN
# 2010-06            NaN
# 2010-07            NaN
# 2010-08            NaN
# 2010-09            NaN
# 2010-10            NaN
# 2010-11            NaN
# 2010-12            NaN
# 2011-01            NaN
# 2011-02            NaN
# 2011-03            NaN
# 2011-04            NaN
# 2011-05            NaN
# 2011-06            NaN
# 2011-07            NaN
# 2011-08            NaN
# 2011-09            NaN
# 2011-10            NaN
# 2011-11            NaN
# 2011-12            NaN
#
# [25 rows x 25 columns]

# %% [markdown]
# #### Step 4:  Heatmap & Interpretation
#
# We will:
# 1) Plot a seaborn heatmap of the **monthly** retention (0–1).
# 2) Write 2–3 sentences on what improves/worsens by Month 1 & Month 2 for UK, and 1 action you’d take.
#
# **Speaker Notes:** Visuals make cohort stories click; ask “what happened around low‑retention cohorts?”

# %%
# Plot heatmap of monthly retention (0–1)
mat_m = retention_m_frac.copy().astype(float).sort_index(axis=0).sort_index(axis=1)
plt.figure(figsize=(20, 10))
ax = sns.heatmap(mat_m, annot=True, fmt=".0%", cbar_kws={"label": "Retention (0–1)"}, vmin=0, vmax=1)
ax.set_title("United Kingdom — Monthly Cohort Retention")
ax.set_xlabel("Months Since First Purchase")
ax.set_ylabel("Cohort (Signup Month)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 👩‍💻 Student-Led Section (20 minutes) -- ANSWER KEY

# %% [markdown]
# ### Step 1: Filter to Germany (DE) and define weekly cohorts
#
#
# 1) Keep rows where `Country == "Germany"`.
# 2) Define **cohort_week** as each customer’s first activity week.
# 3) Define **activity_week** for each row.
# 4) Compute **week_number** = weeks since cohort start.

# %%
# 1) Country filter
de_filter = df['Country'] == 'Germany'
df_de = df[de_filter].copy()

# 2) First activity week (cohort anchor) per customer do your groupby
df_de["cohort_week"] = df_de.groupby(df_de['Customer ID'])['activity_date'].transform(min).dt.to_period('W')

# 3) Activity week per row
df_de["activity_week"] = df_de["activity_date"].dt.to_period("W")

# 4) Weeks since cohort start (subtract cohort week from activity week)
df_de["week_number"] =  (df_de["activity_week"] - df_de["cohort_week"]).apply(lambda x: x.n)

df_de[["Customer ID","activity_date","cohort_week","activity_week","week_number"]].head()
# Out:
# /var/folders/_z/410cfm6x4fl_4m_6s41fnf4w0000gp/T/ipykernel_23793/1652399630.py:5: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df_de["cohort_week"] = df_de.groupby(df_de['Customer ID'])['activity_date'].transform(min).dt.to_period('W')
#      Customer ID       activity_date            cohort_week  \
# 579        12533 2009-12-01 11:50:00  2009-11-30/2009-12-06
# 580        12533 2009-12-01 11:50:00  2009-11-30/2009-12-06
# 581        12533 2009-12-01 11:50:00  2009-11-30/2009-12-06
# 582        12533 2009-12-01 11:50:00  2009-11-30/2009-12-06
# 583        12533 2009-12-01 11:50:00  2009-11-30/2009-12-06
#
#              activity_week  week_number
# 579  2009-11-30/2009-12-06            0
# 580  2009-11-30/2009-12-06            0
# 581  2009-11-30/2009-12-06            0
# 582  2009-11-30/2009-12-06            0
# 583  2009-11-30/2009-12-06            0

# %% [markdown]
# #### Step 2:  Build a **weekly** retention matrix and normalize by cohort size
#
# 1) Count **unique active customers** by (`cohort_week`, `week_number`).
# 2) Pivot to cohorts × weeks.
# 3) Divide each row by **Week 0** to get retention fractions.

# %%
# 1) Unique active customers per (cohort_week, week_number)
cohort_counts_w = df_de.groupby(['cohort_week','week_number'])["Customer ID"].nunique().reset_index()

# 2) Pivot
retention_w = cohort_counts_w.pivot(index='cohort_week',columns='week_number',values='Customer ID')

# 3) Normalize by cohort size (Week 0)
cohort_size_w = retention_w.iloc[:, 0]
retention_w_frac = retention_w.div(cohort_size_w, axis=0)

retention_w_frac
# Out:
# week_number            0         1         2         3         4         5    \
# cohort_week
# 2009-11-30/2009-12-06  1.0  0.500000  0.250000  0.250000       NaN  0.250000
# 2009-12-07/2009-12-13  1.0  0.500000  0.250000       NaN  0.250000  0.750000
# 2009-12-14/2009-12-20  1.0       NaN       NaN       NaN  0.333333  0.333333
# 2010-01-04/2010-01-10  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-01-11/2010-01-17  1.0  0.250000  0.500000  0.500000  0.500000       NaN
# 2010-01-18/2010-01-24  1.0  1.000000       NaN       NaN       NaN       NaN
# 2010-01-25/2010-01-31  1.0       NaN       NaN       NaN       NaN  1.000000
# 2010-02-01/2010-02-07  1.0       NaN       NaN  0.500000       NaN  0.500000
# 2010-02-08/2010-02-14  1.0  0.285714       NaN  0.285714  0.142857  0.142857
# 2010-02-15/2010-02-21  1.0       NaN  1.000000       NaN       NaN       NaN
# 2010-03-01/2010-03-07  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-03-15/2010-03-21  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-03-22/2010-03-28  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-03-29/2010-04-04  1.0       NaN       NaN       NaN  1.000000       NaN
# 2010-04-05/2010-04-11  1.0  1.000000       NaN       NaN       NaN  1.000000
# 2010-04-12/2010-04-18  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-04-19/2010-04-25  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-04-26/2010-05-02  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-05-10/2010-05-16  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-05-24/2010-05-30  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-06-28/2010-07-04  1.0       NaN  0.666667       NaN       NaN  0.666667
# 2010-07-05/2010-07-11  1.0       NaN  0.333333       NaN       NaN       NaN
# 2010-07-19/2010-07-25  1.0       NaN       NaN       NaN  0.333333  0.333333
# 2010-07-26/2010-08-01  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-08-16/2010-08-22  1.0       NaN  1.000000       NaN       NaN       NaN
# 2010-09-06/2010-09-12  1.0       NaN       NaN       NaN       NaN  0.500000
# 2010-09-27/2010-10-03  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-10-18/2010-10-24  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-10-25/2010-10-31  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-11-01/2010-11-07  1.0       NaN       NaN       NaN       NaN       NaN
# 2010-11-29/2010-12-05  1.0       NaN       NaN  0.500000       NaN       NaN
# 2010-12-20/2010-12-26  1.0       NaN  0.500000       NaN       NaN       NaN
# 2011-01-03/2011-01-09  1.0       NaN       NaN  1.000000       NaN       NaN
# 2011-01-17/2011-01-23  1.0  1.000000  1.000000       NaN       NaN       NaN
# 2011-01-24/2011-01-30  1.0  1.000000       NaN       NaN       NaN       NaN
# 2011-01-31/2011-02-06  1.0       NaN       NaN       NaN       NaN  1.000000
# 2011-02-07/2011-02-13  1.0       NaN       NaN       NaN       NaN       NaN
# 2011-02-14/2011-02-20  1.0       NaN       NaN       NaN       NaN       NaN
# 2011-03-07/2011-03-13  1.0  0.500000  0.500000       NaN       NaN       NaN
# 2011-03-28/2011-04-03  1.0       NaN  1.000000  1.000000       NaN  1.000000
# 2011-04-11/2011-04-17  1.0  1.000000       NaN       NaN       NaN       NaN
# 2011-04-18/2011-04-24  1.0       NaN       NaN       NaN       NaN       NaN
# 2011-05-16/2011-05-22  1.0       NaN  1.000000       NaN       NaN       NaN
# 2011-05-30/2011-06-05  1.0  0.500000       NaN       NaN       NaN       NaN
# 2011-07-18/2011-07-24  1.0       NaN  0.333333       NaN  0.333333  0.333333
# 2011-08-01/2011-08-07  1.0       NaN       NaN       NaN       NaN       NaN
# 2011-08-15/2011-08-21  1.0       NaN       NaN       NaN       NaN  1.000000
# 2011-08-22/2011-08-28  1.0       NaN       NaN       NaN       NaN       NaN
# 2011-08-29/2011-09-04  1.0       NaN       NaN       NaN       NaN       NaN
# 2011-09-05/2011-09-11  1.0       NaN       NaN       NaN       NaN       NaN
# 2011-09-12/2011-09-18  1.0       NaN  1.000000       NaN       NaN       NaN
# 2011-09-26/2011-10-02  1.0       NaN  1.000000       NaN       NaN       NaN
# 2011-10-03/2011-10-09  1.0  0.500000       NaN       NaN  0.500000       NaN
# 2011-10-10/2011-10-16  1.0       NaN       NaN       NaN  0.500000  0.500000
# 2011-10-17/2011-10-23  1.0       NaN  0.500000       NaN       NaN       NaN
# 2011-10-31/2011-11-06  1.0       NaN       NaN       NaN       NaN       NaN
# 2011-11-14/2011-11-20  1.0       NaN       NaN       NaN       NaN       NaN
# 2011-11-21/2011-11-27  1.0       NaN       NaN       NaN       NaN       NaN
# 2011-11-28/2011-12-04  1.0  1.000000       NaN       NaN       NaN       NaN
# 2011-12-05/2011-12-11  1.0       NaN       NaN       NaN       NaN       NaN
#
# week_number                 6    7         8         9    ...       96    97   \
# cohort_week                                               ...
# 2009-11-30/2009-12-06  0.500000  NaN  0.250000  0.250000  ...  0.500000  0.25
# 2009-12-07/2009-12-13       NaN  0.5  0.250000  0.500000  ...  0.250000  0.50
# 2009-12-14/2009-12-20       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-01-04/2010-01-10       NaN  NaN       NaN  1.000000  ...       NaN   NaN
# 2010-01-11/2010-01-17  0.250000  0.5       NaN  0.250000  ...  0.250000   NaN
# 2010-01-18/2010-01-24       NaN  NaN  0.333333       NaN  ...  0.333333   NaN
# 2010-01-25/2010-01-31  0.500000  NaN       NaN       NaN  ...  0.500000   NaN
# 2010-02-01/2010-02-07  0.500000  NaN       NaN  1.000000  ...       NaN   NaN
# 2010-02-08/2010-02-14  0.285714  NaN       NaN  0.142857  ...       NaN   NaN
# 2010-02-15/2010-02-21       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-03-01/2010-03-07       NaN  0.5       NaN       NaN  ...       NaN   NaN
# 2010-03-15/2010-03-21       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-03-22/2010-03-28       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-03-29/2010-04-04       NaN  1.0       NaN       NaN  ...       NaN   NaN
# 2010-04-05/2010-04-11       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-04-12/2010-04-18       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-04-19/2010-04-25       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-04-26/2010-05-02       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-05-10/2010-05-16       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-05-24/2010-05-30  0.333333  NaN       NaN       NaN  ...       NaN   NaN
# 2010-06-28/2010-07-04  0.333333  NaN       NaN       NaN  ...       NaN   NaN
# 2010-07-05/2010-07-11       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-07-19/2010-07-25  0.333333  NaN       NaN       NaN  ...       NaN   NaN
# 2010-07-26/2010-08-01       NaN  1.0       NaN  1.000000  ...       NaN   NaN
# 2010-08-16/2010-08-22       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-09-06/2010-09-12       NaN  NaN       NaN  0.500000  ...       NaN   NaN
# 2010-09-27/2010-10-03       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-10-18/2010-10-24       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-10-25/2010-10-31       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-11-01/2010-11-07       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-11-29/2010-12-05       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2010-12-20/2010-12-26       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-01-03/2011-01-09       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-01-17/2011-01-23       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-01-24/2011-01-30       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-01-31/2011-02-06       NaN  1.0       NaN       NaN  ...       NaN   NaN
# 2011-02-07/2011-02-13       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-02-14/2011-02-20       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-03-07/2011-03-13       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-03-28/2011-04-03       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-04-11/2011-04-17       NaN  NaN  1.000000       NaN  ...       NaN   NaN
# 2011-04-18/2011-04-24       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-05-16/2011-05-22  1.000000  NaN       NaN       NaN  ...       NaN   NaN
# 2011-05-30/2011-06-05       NaN  NaN       NaN  0.500000  ...       NaN   NaN
# 2011-07-18/2011-07-24  0.666667  NaN       NaN       NaN  ...       NaN   NaN
# 2011-08-01/2011-08-07       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-08-15/2011-08-21       NaN  NaN  1.000000       NaN  ...       NaN   NaN
# 2011-08-22/2011-08-28  0.500000  NaN  0.500000  0.500000  ...       NaN   NaN
# 2011-08-29/2011-09-04       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-09-05/2011-09-11  1.000000  NaN       NaN       NaN  ...       NaN   NaN
# 2011-09-12/2011-09-18       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-09-26/2011-10-02       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-10-03/2011-10-09  0.500000  0.5       NaN  0.500000  ...       NaN   NaN
# 2011-10-10/2011-10-16       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-10-17/2011-10-23  0.500000  NaN       NaN       NaN  ...       NaN   NaN
# 2011-10-31/2011-11-06       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-11-14/2011-11-20       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-11-21/2011-11-27       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-11-28/2011-12-04       NaN  NaN       NaN       NaN  ...       NaN   NaN
# 2011-12-05/2011-12-11       NaN  NaN       NaN       NaN  ...       NaN   NaN
#
# week_number             98        99    100   101   102  103   104   105
# cohort_week
# 2009-11-30/2009-12-06   NaN  0.500000  0.50  0.25  0.25  0.5  0.25  0.25
# 2009-12-07/2009-12-13  0.25       NaN  0.75  0.25  0.25  NaN  0.25   NaN
# 2009-12-14/2009-12-20   NaN  0.666667   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-01-04/2010-01-10   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-01-11/2010-01-17   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-01-18/2010-01-24   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-01-25/2010-01-31   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-02-01/2010-02-07   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-02-08/2010-02-14   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-02-15/2010-02-21   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-03-01/2010-03-07   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-03-15/2010-03-21   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-03-22/2010-03-28   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-03-29/2010-04-04   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-04-05/2010-04-11   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-04-12/2010-04-18   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-04-19/2010-04-25   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-04-26/2010-05-02   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-05-10/2010-05-16   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-05-24/2010-05-30   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-06-28/2010-07-04   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-07-05/2010-07-11   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-07-19/2010-07-25   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-07-26/2010-08-01   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-08-16/2010-08-22   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-09-06/2010-09-12   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-09-27/2010-10-03   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-10-18/2010-10-24   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-10-25/2010-10-31   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-11-01/2010-11-07   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-11-29/2010-12-05   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2010-12-20/2010-12-26   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-01-03/2011-01-09   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-01-17/2011-01-23   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-01-24/2011-01-30   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-01-31/2011-02-06   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-02-07/2011-02-13   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-02-14/2011-02-20   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-03-07/2011-03-13   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-03-28/2011-04-03   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-04-11/2011-04-17   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-04-18/2011-04-24   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-05-16/2011-05-22   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-05-30/2011-06-05   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-07-18/2011-07-24   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-08-01/2011-08-07   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-08-15/2011-08-21   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-08-22/2011-08-28   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-08-29/2011-09-04   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-09-05/2011-09-11   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-09-12/2011-09-18   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-09-26/2011-10-02   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-10-03/2011-10-09   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-10-10/2011-10-16   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-10-17/2011-10-23   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-10-31/2011-11-06   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-11-14/2011-11-20   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-11-21/2011-11-27   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-11-28/2011-12-04   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 2011-12-05/2011-12-11   NaN       NaN   NaN   NaN   NaN  NaN   NaN   NaN
#
# [60 rows x 106 columns]

# %% [markdown]
# ### Step 3:  Weekly heatmap & interpretation (Can be hard to see all weeks together -- try filtering OR Tableau on your own later)
#
# 1) Plot a seaborn heatmap of weekly retention (0–1).
# 2) Write 2–3 sentences interpreting where Germany shows stronger/weaker weekly retention and one hypothesis for *why*.

# %%
# Plot heatmap of weekly retention (0–1)
mat_w = retention_w_frac.copy().astype(float).sort_index(axis=0).sort_index(axis=1)
plt.figure(figsize=(20, 10))
ax = sns.heatmap(mat_w, annot=False, fmt=".0%", cbar_kws={"label": "Retention (0–1)"}, vmin=0, vmax=1)
ax.set_title("Germany — Weekly Cohort Retention")
ax.set_xlabel("Weeks Since First Purchase")
ax.set_ylabel("Cohort (Signup Week)")
plt.tight_layout()
plt.show()

# Germany shows weaker retention because it's on a weekly basis. Customers usually don't need to purchase more than once a week so there are large drops in between weeks.

# %% [markdown]
# ### Wrap‑Up: Reading & Acting on Cohorts -- (15 mins)
#
# **Students:  Be prepared to reflect and answer the interview questions at the top of this notebook.**
#
# - **Time matters:** Cohorts track the *same users* over time; MAU can hide churn if new users replace old ones.
# - **Granularity choice:** Weekly cohorts reveal short‑term dynamics (promos, bugs); monthly cohorts smooth noise but may hide spikes.
# - **Market differences:** UK monthly vs Germany weekly shows how market and period choice change the narrative.
# - **Actions:** If Month/Week‑1 retention dips, audit onboarding, returns/shipping policy, payment UX, or marketing sources in that signup window.
# - **Next:** Segment cohorts by acquisition channel or product category to find who sticks and why. Tie changes to a single success metric (e.g., +5pp in Month‑1 retention for new cohorts).
